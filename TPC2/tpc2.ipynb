# %%
#Jogo dos fosforos

print("Bem-vindo ao jogo dos fósforos!")
print("Regras:")
print("- Começamos com 21 fósforos.")
print("- Em cada rodada, o jogador escolhe tirar 1 a 4 fósforos.")
print("- Quem retirar o último fósforo perde!")
print("------------------------------------------------------------")

n1 = 21
jogador = int(input("Queres ser o primeiro ou o segundo jogador? (1/2)"))

if jogador==1:
    print("Com que então queres ser o primeiro jogador...")
    print("Vamos lá começar!")
    while n1 > 1:
        retirar = int(input("Escolhe o número de fósforos que queres retirar (1/2/3/4):"))
        n1 = n1 - retirar
        print(f"Sobram {n1} fóforos")
        if n1 > 1:
            print("É a vez de o computador jogar")
            computador=(n1 - 1) % 5
            if computador == 0:
                computador = 1
            if computador > n1 - 1:
                computador = n1 - 1
            print(f"O computador tirou {computador} fósforos")
            n1 = n1 - computador
            print(f"Restam {n1} fósforos")
        if n1 == 1:
            print("Perdeste o jogo!!!")
            break

elif jogador==2:
    print("Com que então queres ser o segundo jogador...")
    print("Vamos lá começar!")
    while n1 > 4:
        import random
        n2 = random.randint(1, 4)
        print(f"O computador tirou {n2} fósforos")
        n1 = n1 - n2
        print(f"Restam {n1} fósforos")
        if n1 > 1:
            print("É a tua vez de jogar")
            retirar = int(input("Escolhe o número de fósforos que queres retirar (1/2/3/4):"))
            n1 = n1 - retirar
            print(f"Sobram {n1} fóforos")
        if n1 == 1:
            print("Ganhas-te o jogo") 
        if n1 == 0:
            print("O computador ganhou!!! ")
  
    while 1 < n1 <= 4:
        computador=(n1 - 1) % 5
        if computador == 0:
            computador = 1
        if computador > n1 - 1:
            computador = n1 - 1
        print(f"O computador tirou {computador} fósforos")
        n1 = n1 - computador
        print(f"Restam {n1} fósforos")
        if n1 == 1:
            print("O computador ganhou!!! ")
# Out:
# Bem-vindo ao jogo dos fósforos!
# Regras:
# - Começamos com 21 fósforos.
# - Em cada rodada, o jogador escolhe tirar 1 a 4 fósforos.
# - Quem retirar o último fósforo perde!
# ------------------------------------------------------------
# Com que então queres ser o segundo jogador...
# Vamos lá começar!
# O computador tirou 4 fósforos
# Restam 17 fósforos
# É a tua vez de jogar
# Sobram 13 fóforos
# O computador tirou 1 fósforos
# Restam 12 fósforos
# É a tua vez de jogar
# Sobram 10 fóforos
# O computador tirou 2 fósforos
# Restam 8 fósforos
# É a tua vez de jogar
# Sobram 6 fóforos
# O computador tirou 3 fósforos
# Restam 3 fósforos
# É a tua vez de jogar
# Sobram 0 fóforos
# O computador ganhou!!!
